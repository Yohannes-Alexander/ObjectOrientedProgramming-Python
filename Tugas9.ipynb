# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    @abstractmethod
    def makeSound(self):
        pass
    
    def eat(self):
        print('I can eat')
    
    def sleep(self):
        print('I need to sleep')

class Cat(Animal):
    
    def makeSound(self):
        print('Meow meow')

        
cat1 = Cat()
cat1.makeSound()
cat1.eat()
cat.sleep()
# Out:
# Meow meow
# I can eat
# I need to sleep

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            self.name = name
            self.canFly = canFly
        elif(name!=None):
            self.name = name
            self.canFly = False
    
    def getName(self):
        return self.name
    
    def getCanFly(self):
        return self.canFly
    
    @abstractmethod
    def makeSound(self):
        pass
    
    @abstractmethod
    def myName(self):
        pass
    
    def eat(self):
        print('I can eat')
    
    def sleep(self):
        print('I need to sleep')

class Cat(Animal):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            super().__init__(name,canFly)
        elif(name!=None ):
            super().__init__(name)
    
    def makeSound(self):
        print('Meow meow')
    
    def myName(self):
        print("My name is ",self.getName())

        
cat1 = Cat("Catty",False)
cat1.makeSound()
cat1.myName()
print('can i fly to the sky ? ',cat1.getCanFly())
cat1.eat()
cat1.sleep()
# Out:
# Meow meow
# My name is  Catty
# can i fly to the sky ?  False
# I can eat
# I need to sleep

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            self.name = name
            self.canFly = canFly
        elif(name!=None):
            self.name = name
            self.canFly = False
    
    def getName(self):
        return self.name
    
    def getCanFly(self):
        return self.canFly
    
    @abstractmethod
    def makeSound(self):
        pass
    
    @abstractmethod
    def myName(self):
        pass
    
    def eat(self):
        print('I can eat')
    
    def sleep(self):
        print('I need to sleep')
    
    def toString(self):
        result = 'tidak' if self.getCanFly()==False else 'bisa'
        return f'{self.getName()} dan termasuk hewan yang {result} bisa terbang'

class Cat(Animal):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            super().__init__(name,canFly)
        elif(name!=None ):
            super().__init__(name)
    
    def makeSound(self):
        return "Meow meow"
    
    def myName(self):
        print("My name is ",self.getName())
    
    def toString(self):
        return f'{super().toString()} serta bersuara {self.makeSound()} '
        

        
cat1 = Cat("Catty",False)
print(cat1.makeSound())
cat1.myName()
print('can i fly to the sky ? ',cat1.getCanFly())
cat1.eat()
cat1.sleep()
print("Kucing ini bernama",cat1.toString())
# Out:
# Meow meow
# My name is  Catty
# can i fly to the sky ?  False
# I can eat
# I need to sleep
# Kucing ini bernama Catty dan termasuk hewan yang tidak bisa terbang serta bersuara Meow meow

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            self.name = name
            self.canFly = canFly
        elif(name!=None):
            self.name = name
            self.canFly = False
    
    def getName(self):
        return self.name
    
    def getCanFly(self):
        return self.canFly
    
    @abstractmethod
    def makeSound(self):
        pass
    
    @abstractmethod
    def myName(self):
        pass
    
    def eat(self):
        print('I can eat')
    
    def sleep(self):
        print('I need to sleep')
    
    @abstractmethod
    def toString(self):
        result = 'tidak' if self.getCanFly()==False else 'bisa'
        return f'{self.getName()} dan termasuk hewan yang {result} bisa terbang'

class Cat(Animal):
    
    def __init__(self, name=None, canFly=None):
        if(name!=None and canFly!=None):
            super().__init__(name,canFly)
        elif(name!=None ):
            super().__init__(name)
    
    def makeSound(self):
        return "Meow meow"
    
    def myName(self):
        print("My name is ",self.getName())
    
    def toString(self):
        return f'{super().toString()} serta bersuara {self.makeSound()} '
        

        
cat1 = Cat("Pussy",False)
print(cat1.makeSound())
cat1.myName()
print('can i fly to the sky ? ',cat1.getCanFly())
cat1.eat()
cat1.sleep()
print("Kucing ini bernama",cat1.toString())
# Out:
# Meow meow
# My name is  Pussy
# can i fly to the sky ?  False
# I can eat
# I need to sleep
# Kucing ini bernama Pussy dan termasuk hewan yang tidak bisa terbang serta bersuara Meow meow
